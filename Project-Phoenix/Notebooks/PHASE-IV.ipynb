# %% [markdown]
# # PHASE IV: Control Notebook

# %%
import time
from run_objects.scan import scan
from run_objects.sys3CS import sys3CS
import pyfirmata
import os
# Out:
# Python Executable Path: C:\Users\Physics\Anaconda3\python.exe

# %%
# Scan Params
Duration       = 30  #seconds
Raman_duration = 0.5 #seconds
Iterations     = 10

# Paths
path_to_phase = "D:\\CC Hargy\\Project-Phoenix\\PHASE-IV"

# %%
# Functions
def take_exposure(sys, time, savepath=None):
    
    # Set exposure time
    sys.ctrl(spec_exp=time)
    
    # Open laser shutter
    boardMAR.digital[13].write(1)
    
    # Open spectro shutter
    sys.ctrl(spec_shutter=True)
    
    # Run
    sys.ctrl(spec_run=True)
    
    # Close both shutters
    sys.ctrl(spec_shutter=False)
    boardMAR.digital[13].write(0)
    
    if savepath != None:
            sys.ctrl(spec_save=savepath)
    
    sys.ctrl(spec_clear_screen=True)

def take_ambience(sys, time, savepath=None):
    
    # Set exposure time
    sys.ctrl(spec_exp=time)
    
    # Make sure laser shutter closed
    boardMAR.digital[13].write(0)
    
    # Open spectro shutter
    sys.ctrl(spec_shutter=True)
    
    # Run
    sys.ctrl(spec_run=True)
    
    # Close shutter
    sys.ctrl(spec_shutter=False)
    
    if savepath != None:
            sys.ctrl(spec_save=savepath)
    
    sys.ctrl(spec_clear_screen=True)

def take_baseline(sys, time, savepath=None):
    
    # Set exposure time
    sys.ctrl(spec_exp=time)
    
    # Make sure laser shutter closed
    boardMAR.digital[13].write(0)
    
    # Make sure spectro shutter closed
    sys.ctrl(spec_shutter=False)
    
    # Run
    sys.ctrl(spec_run=True)
    
    if savepath != None:
            sys.ctrl(spec_save=savepath)
    
    sys.ctrl(spec_clear_screen=True)

# %%
# instantiate object
sys = sys3CS()
boardMAR = pyfirmata.Arduino("COM23")
# Out:
# 15/10/2025  13:36:55 [ ] Initialised SystemClient object from C:/rep_py3cs/py3cs/Server/dev_config.json
# 15/10/2025  13:36:55 [ ] Connecting to source_power ...
# 15/10/2025  13:36:58 [ ] Failed to connect to source_power
# 15/10/2025  13:36:58 [ ] Connecting to source_shutter_control ...
# 15/10/2025  13:37:01 [ ] Connected! Reading: computer
# 15/10/2025  13:37:01 [ ] Connecting to source_shutter_on ...
# 15/10/2025  13:37:04 [ ] Failed to connect to source_shutter_on
# 15/10/2025  13:37:04 [ ] Connecting to spf ...
# 15/10/2025  13:37:05 [ ] Connected! Reading: DEVICE NOT OPEN
# 15/10/2025  13:37:05 [ ] Connecting to lpf ...
# 15/10/2025  13:37:10 [ ] Connected! Reading: 3
# 15/10/2025  13:37:10 [ ] Connecting to lpf2 ...
# 15/10/2025  13:37:12 [ ] Connected! Reading: DEVICE NOT OPEN
# 15/10/2025  13:37:12 [ ] Connecting to flipperA ...
# 15/10/2025  13:37:16 [ ] Failed to connect to flipperA
# 15/10/2025  13:37:16 [ ] Connecting to flipperB ...
# 15/10/2025  13:37:17 [ ] Connected! Reading: unknown
# 15/10/2025  13:37:17 [ ] Connecting to mono ...
# 15/10/2025  13:37:20 [ ] Failed to connect to mono
# 15/10/2025  13:37:20 [ ] Connecting to spectrograph ...
# 15/10/2025  13:37:25 [ ] Connected! Reading: spec_gr=2, spec_shutter=Not a valid command, spec_wl=630, spec_exp=1
# 15/10/2025  13:37:25 [ ] Connecting to power metre a ...
# 15/10/2025  13:37:29 [ ] Failed to connect to power metre a
# 15/10/2025  13:37:29 [ ] Connecting to power metre b ...
# 15/10/2025  13:37:32 [ ] Failed to connect to power metre b
# 15/10/2025  13:37:32 [ ] Connecting to power metre t ...
# 15/10/2025  13:37:35 [ ] Connected! Reading: pm_t_wl=445, pm_t_unit=POW, pm_t_count=1
# 15/10/2025  13:37:35 [ ] Mono_slit manually set to 1000

# %% [markdown]
# ## 💎 COLL 1 💎

# %%
# Set collection params
coll = "Coll1"

# %% [markdown]
# ### 1. Baseline (BL)

# %%
sample = "BL"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_baseline(sys, Duration, save_path)
    print()
# Out:
# 15/10/2025  15:43:40 [ ] spec_exp already set to 1
# 15/10/2025  15:43:40 [ ] spec_shutter already set to False
# 15/10/2025  15:43:40 [ ] Taking spectrum ...
# 15/10/2025  15:43:44 [ ] Done.
# 15/10/2025  15:43:44 [ ] Saving spectrum ...
# 15/10/2025  15:43:46 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\BL\it_0.txt
# 15/10/2025  15:43:46 [ ] Solis file created.
# 15/10/2025  15:43:46 [ ] Extracted data and metadata
# 15/10/2025  15:43:46 [ ] Clearing screen
# 15/10/2025  15:43:48 [ ] Clearing screen
# 15/10/2025  15:43:49 [ ] spec_exp already set to 1
# 15/10/2025  15:43:49 [ ] spec_shutter already set to False
# 15/10/2025  15:43:49 [ ] Taking spectrum ...
# 15/10/2025  15:43:53 [ ] Done.
# 15/10/2025  15:43:53 [ ] Saving spectrum ...
# 15/10/2025  15:43:56 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\BL\it_1.txt
# 15/10/2025  15:43:56 [ ] Solis file created.
# 15/10/2025  15:43:56 [ ] Extracted data and metadata
# 15/10/2025  15:43:56 [ ] Clearing screen
# 15/10/2025  15:43:57 [ ] Clearing screen
# 15/10/2025  15:43:58 [ ] spec_exp already set to 1
# 15/10/2025  15:43:58 [ ] spec_shutter already set to False
# 15/10/2025  15:43:58 [ ] Taking spectrum ...
# 15/10/2025  15:44:02 [ ] Done.
# 15/10/2025  15:44:02 [ ] Saving spectrum ...
# 15/10/2025  15:44:05 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\BL\it_2.txt
# 15/10/2025  15:44:05 [ ] Solis file created.
# 15/10/2025  15:44:05 [ ] Extracted data and metadata
# 15/10/2025  15:44:05 [ ] Clearing screen
# 15/10/2025  15:44:06 [ ] Clearing screen
# 15/10/2025  15:44:07 [ ] spec_exp already set to 1
# 15/10/2025  15:44:07 [ ] spec_shutter already set to False
# 15/10/2025  15:44:07 [ ] Taking spectrum ...
# 15/10/2025  15:44:12 [ ] Done.
# 15/10/2025  15:44:12 [ ] Saving spectrum ...
# 15/10/2025  15:44:14 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\BL\it
[ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\BL\it_9.txt
# 15/10/2025  15:45:09 [ ] Solis file created.
# 15/10/2025  15:45:09 [ ] Extracted data and metadata
# 15/10/2025  15:45:09 [ ] Clearing screen
# 15/10/2025  15:45:10 [ ] Clearing screen

# %% [markdown]
# ### 2. Ambience (AM)

# %%
sample = "AM"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_ambience(sys, Duration, save_path)
    print()
# Out:
# Iteration:  0
# 15/10/2025  15:54:03 [ ] spec_exp already set to 1
# 15/10/2025  15:54:03 [ ] Setting spec_shutter to True
# 15/10/2025  15:54:05 [ ] Set
# 15/10/2025  15:54:05 [ ] Taking spectrum ...
# 15/10/2025  15:54:09 [ ] Done.
# 15/10/2025  15:54:09 [ ] Setting spec_shutter to False
# 15/10/2025  15:54:10 [ ] Set
# 15/10/2025  15:54:10 [ ] Saving spectrum ...
# 15/10/2025  15:54:13 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it_0.txt
# 15/10/2025  15:54:13 [ ] Solis file created.
# 15/10/2025  15:54:13 [ ] Extracted data and metadata
# 15/10/2025  15:54:13 [ ] Clearing screen
# 15/10/2025  15:54:14 [ ] Clearing screen
#
# Iteration:  1
# 15/10/2025  15:54:15 [ ] spec_exp already set to 1
# 15/10/2025  15:54:15 [ ] Setting spec_shutter to True
# 15/10/2025  15:54:17 [ ] Set
# 15/10/2025  15:54:17 [ ] Taking spectrum ...
# 15/10/2025  15:54:21 [ ] Done.
# 15/10/2025  15:54:21 [ ] Setting spec_shutter to False
# 15/10/2025  15:54:22 [ ] Set
# 15/10/2025  15:54:22 [ ] Saving spectrum ...
# 15/10/2025  15:54:25 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it_1.txt
# 15/10/2025  15:54:25 [ ] Solis file created.
# 15/10/2025  15:54:25 [ ] Extracted data and metadata
# 15/10/2025  15:54:25 [ ] Clearing screen
# 15/10/2025  15:54:26 [ ] Clearing screen
#
# Iteration:  2
# 15/10/2025  15:54:27 [ ] spec_exp already set to 1
# 15/10/2025  15:54:27 [ ] Setting spec_shutter to True
# 15/10/2025  15:54:29 [ ] Set
# 15/10/2025  15:54:29 [ ] Taking spectrum ...
# 15/10/2025  15:54:33 [ ] Done.
# 15/10/2025  15:54:33 [ ] Setting spec_shutter to False
# 15/10/2025  15:54:35 [ ] Set
# 15/10/2025  15:54:35 [ ] Saving spectrum ...
# 15/10/2025  15:54:37 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it_2.txt
# 15/10/2025  15:54:37 [ ] Solis file created.
# 15/10/2025  15:54:37 [ ] Extracted data and metadata
# 15/10/2025  15:54:37 [ ] Clearing screen
# 15/10/2025  15:54:38 [ ] Clearing screen
#
# Iteration:  3
# 15/10/2025  15:54:40 [ ] spec_exp already set to 1
# 15/10/2025  15:54:40 [ ] Setting spec_shutter to True
# 15/10/2025  15:54:41 [ ] Set
# 15/10/2025  15:54:41 [ ] Taking spectrum ...
# 15/10/2025  15:54:45 [ ] Done.
# 15/10/2025  15:54:45 [ ] Setting spec_shutter to False
# 15/10/2025  15:54:47 [ ] Set
# 15/10/2025  15:54:47 [ ] Saving spectrum ...
# 15/10/2025  15:54:49 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it
[ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it_8.txt
# 15/10/2025  15:55:50 [ ] Solis file created.
# 15/10/2025  15:55:50 [ ] Extracted data and metadata
# 15/10/2025  15:55:50 [ ] Clearing screen
# 15/10/2025  15:55:51 [ ] Clearing screen
#
# Iteration:  9
# 15/10/2025  15:55:52 [ ] spec_exp already set to 1
# 15/10/2025  15:55:52 [ ] Setting spec_shutter to True
# 15/10/2025  15:55:53 [ ] Set
# 15/10/2025  15:55:53 [ ] Taking spectrum ...
# 15/10/2025  15:55:58 [ ] Done.
# 15/10/2025  15:55:58 [ ] Setting spec_shutter to False
# 15/10/2025  15:55:59 [ ] Set
# 15/10/2025  15:55:59 [ ] Saving spectrum ...
# 15/10/2025  15:56:02 [ ] Saved spectrum to D:\CC Hargy\Project-Phoenix\PHASE-I\Coll1\AM\it_9.txt
# 15/10/2025  15:56:02 [ ] Solis file created.
# 15/10/2025  15:56:02 [ ] Extracted data and metadata
# 15/10/2025  15:56:02 [ ] Clearing screen
# 15/10/2025  15:56:03 [ ] Clearing screen

# %% [markdown]
# ### 3. Raman (H2O)

# %%
sample = "H2O"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Raman_duration, save_path)
    print()

# %% [markdown]
# ### 4. Sapphire Dummy (SP_B2_35)

# %%
sample = "SP_B2_35"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 5. 🔴 CONTROL: LiF10_116

# %%
sample = "LiF10_116"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 6. 🔘 LiF10_117

# %%
sample = "LiF10_117"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66441093f514> in <module>()
#       1 sample = "LiF10_113"
# ----> 2 for it in range(Iterations):
#       3     print("Iteration: ", it)
#       4     save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
#       5     take_exposure(sys, Duration, save_path)
#
# NameError: name 'Iterations' is not defined

# %% [markdown]
# ### 7. 🔘 LiF10_118

# %%
sample = "LiF10_118"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 7. 🔘 LiF10_119

# %%
sample = "LiF10_119"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 7. 🔘 LiF10_120

# %%
sample = "LiF10_120"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ---

# %% [markdown]
# ## 💎 COLL 2 💎

# %%
# Set collection params
coll = "Coll2"

# %% [markdown]
# ### 1. Baseline (BL)

# %%
sample = "BL"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_baseline(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 2. Ambience (AM)

# %%
sample = "AM"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_ambience(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 3. Raman (H2O)

# %%
sample = "H2O"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Raman_duration, save_path)
    print()

# %% [markdown]
# ### 4. Sapphire Dummy (SP_B2_35)

# %%
sample = "SP_B2_35"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 5. 🔴 CONTROL: LiF10_116

# %%
sample = "LiF10_116"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 6. 🔘 LiF10_117

# %%
sample = "LiF10_117"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 7. 🔘 LiF10_118

# %%
sample = "LiF10_118"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 7. 🔘 LiF10_119

# %%
sample = "LiF10_119"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ### 7. 🔘 LiF10_120

# %%
sample = "LiF10_120"
for it in range(Iterations):
    print("Iteration: ", it)
    save_path = os.path.join(path_to_phase, f"{coll}\\{sample}\\it_{it}.txt")
    take_exposure(sys, Duration, save_path)
    print()

# %% [markdown]
# ---

# %% [markdown]
# # THE END
